# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
from astropy.io import ascii
from matplotlib.ticker import MultipleLocator

# %%
fluxtabdir = '/home/jovyan/carmaedge/comb_de/native/mom/'
lintyp = 'co'
momtyp = 'dil'
nx=7
ny=5

# %%
filelist = glob.glob(fluxtabdir+'*.'+lintyp+'.*'+momtyp+'.flux.out')
print('There are {} galaxies'.format(len(filelist)))
print(fluxtabdir+'*.'+lintyp+'.*'+momtyp+'flux.out')
# Out:
# There are 128 galaxies
# /home/jovyan/carmaedge/comb_de/native/mom/*.co.*dilflux.out

# %%
pages = int(np.ceil(float(len(filelist)) / (nx*ny)))

for num in range(0,pages):
    aa = nx*ny*num
    bb = nx*ny+aa
    sublist = filelist[aa:bb]

    figure = plt.figure(0)
    figure.set_size_inches(nx*4.5, ny*4.)

    for fname in sublist:
        index = sublist.index(fname)
        row,col = divmod(index,nx)
        ax = plt.subplot2grid((ny,nx),(row,col))
        ax.axhline(y=0, xmin=0, xmax=1, color = 'black')

        if os.path.isfile(fname):
            data = ascii.read(fname)
            gal = (os.path.basename(fname)).split('.')[0]

            vel    = data['col1']
            flux   = data['col2']
            eflux  = data['col3']
            ceflux = data['col4']
            deltv  = vel[1]-vel[0]

            imax = max(1,np.ceil(0.25+max(2*flux)))
            ax.set_xlim(vel[0], vel[-1])
            ax.set_ylim([-0.15*imax, 0.6*imax])
            plt.tick_params(axis='x', labelsize='medium')
            plt.tick_params(axis='y', labelsize='medium')

            spec  = ax.step(vel, flux, color = 'b', where='mid')
            start, end = ax.get_xlim()
            if (end-start)>1000:
                majorLocator = MultipleLocator(400)
            else:
                majorLocator = MultipleLocator(200)
            ax.xaxis.set_major_locator(majorLocator)
            if momtyp == 'dil' or type == 'smo':
                ax.fill_between(vel, flux-eflux, flux+eflux, step='mid',
                                facecolor='steelblue', alpha=0.6)
        ax.set_title(gal, fontsize='large')

    figure.text(0.5, 0.06, 'VELO-LSR (km/s)', ha='center',
                fontsize='xx-large')
    figure.text(0.1, 0.5, 'Flux(Jy)', va='center', rotation='vertical', 
                fontsize='xx-large')
    plt.show()
    plt.close()
