# %% [markdown]
# # This notebook shows some examples of exploring the available tables and displaying them in a notebook.

# %% [markdown]
# ## Sanity checks after installation

# %% [markdown]
# #### Show where the package was installed:

# %%
import edge_pydb
print(edge_pydb.__path__)
# Out:
# ['/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb']

# %% [markdown]
# #### Show the names of the available tables

# %%
edge_pydb.util.listfiles()
# Out:
# ['NGC4047.pipe3d.hdf5',
#  'NGC4047.cocube_smo7.hdf5',
#  'edge_bbpars_smo7.csv',
#  'edge_rfpars.csv',
#  'edge_rdist17.csv',
#  'edge_jampars.csv',
#  'edge_bbpars_natv.csv',
#  'edge_califa.csv',
#  'edge_coflux_natv.csv',
#  'edge_hiflux.csv',
#  'edge_coobs_DE.csv',
#  'edge_coflux_e20.csv',
#  'edge_coflux_smo7.csv',
#  'edge_coobs_E.csv',
#  'edge_coobs_D.csv',
#  'edge_wise.csv',
#  'edge_nsa.csv',
#  'edge_ned.csv',
#  'edge_leda.csv',
#  'NGC4047_hex.2d_smo7.hdf5',
#  'NGC4047.2d_smo7.hdf5',
#  'rf_CO_natv.csv',
#  'rf_HA_smo6.csv',
#  'rf_CO_smo6.csv',
#  'rf_HA_natv.csv',
#  'jam_rotcurves.csv',
#  'rprof_de20_smo.csv',
#  'rprof_smo7_smo.csv',
#  'bb_smo7_fixvd_dilmsk_freepa.csv',
#  'bb_smo7_fixvd_dilmsk.csv',
#  'bb_natv_fitvd_dilmsk.csv',
#  'bb_natv_fixvd_dilmsk_freepa.csv',
#  'bb_smo7_fitvd_dilmsk.csv',
#  'bb_natv_fixvd_dilmsk.csv',
#  'bb_natv_fitvd_dilmsk_freepa.csv',
#  'bb_smo7_fitvd_dilmsk_freepa.csv',
#  'cospec_iram.csv',
#  'edge.cocube_smo7.hdf5',
#  'edge.comom_smo7.hdf5',
#  'edge.pipe3d.hdf5',
#  'edge178_leda.csv',
#  'edge_aca.2d_smo9.hdf5',
#  'edge_aca.pipe3d.hdf5',
#  'edge_aca_allpix.2d_smo9.hdf5',
#  'edge_allpix.comom_smo7.hdf5',
#  'edge_allpix.pipe3d.hdf5',
#  'edge_califa_2019.csv',
#  'edge_carma.2d_smo7.hdf5',
#  'edge_carma.pipe3d.hdf5',
#  'edge_carma_allpix.2d_smo7.hdf5',
#  'edge_coflux_iram.csv',
#  'edge_cospec_E20.csv',
#  'edge_cospec_natv.csv',
#  'edge_cospec_smo7.csv',
#  'edge_hex.comom_smo7.hdf5',
#  'edge_hex.pipe3d.hdf5',
#  'edge_hispectra.csv',
#  'edge_xsm.pipe3d.hdf5',
#  'edgealma_hiflux.csv',
#  'edgealma_hispectra.csv']

# %% [markdown]
# #### Show the full paths of the available tables

# %%
edge_pydb.util.listfiles(values=True)
# Out:
# ['/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/img_califa/NGC4047.pipe3d.hdf5',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/img_cocube/NGC4047.cocube_smo7.hdf5',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/derived/edge_bbpars_smo7.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/derived/edge_rfpars.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/derived/edge_rdist17.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/derived/edge_jampars.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/derived/edge_bbpars_natv.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/califa/edge_califa.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coflux_natv.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_hiflux.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coobs_DE.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coflux_e20.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coflux_smo7.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coobs_E.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/obs/edge_coobs_D.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/external/edge_wise.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/external/edge_nsa.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/external/edge_ned.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_glob/external/edge_leda.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/img_comom/NGC4047_hex.2d_smo7.hdf5',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/img_comom/NGC4047.2d_smo7.hdf5',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/rotcur_levy/rf_CO_natv.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/rotcur_levy/rf_HA_smo6.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/rotcur_levy/rf_CO_smo6.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/rotcur_levy/rf_HA_natv.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/rotcur_leung/jam_rotcurves.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/radprof/rprof_de20_smo.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/radprof/rprof_smo7_smo.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_smo7_fixvd_dilmsk_freepa.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_smo7_fixvd_dilmsk.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_natv_fitvd_dilmsk.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_natv_fixvd_dilmsk_freepa.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_smo7_fitvd_dilmsk.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_natv_fixvd_dilmsk.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_natv_fitvd_dilmsk_freepa.csv',
#  '/Users/tonywong/Library/Python/3.7/lib/python/site-packages/edge_pydb/dat_prof/bbarolo/bb_smo7_fitvd_dilmsk_freepa.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/cospec_iram.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge.cocube_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge.comom_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge178_leda.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_aca.2d_smo9.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_aca.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_aca_allpix.2d_smo9.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_allpix.comom_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_allpix.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_califa_2019.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_carma.2d_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_carma.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_carma_allpix.2d_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_coflux_iram.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_cospec_E20.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_cospec_natv.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_cospec_smo7.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_hex.comom_smo7.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_hex.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_hispectra.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edge_xsm.pipe3d.hdf5',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edgealma_hiflux.csv',
#  '/Users/tonywong/Scratch2/EDGE/pybase/edgealma_hispectra.csv']

# %% [markdown]
# ## Regular Usage
# ### In most situations you won't need to import everything; this following import will suffice.

# %%
from edge_pydb import EdgeTable

# %% [markdown]
# ### Make a list of the available tables.
# ### These tables either came with the github repo, or were downloaded using the 'team_files.py' script.

# %%
EdgeTable('list')
# Out:
# Choose from the following files to read:
# NGC4047.pipe3d.hdf5
# NGC4047.cocube_smo7.hdf5
# edge_bbpars_smo7.csv
# edge_rfpars.csv
# edge_rdist17.csv
# edge_jampars.csv
# edge_bbpars_natv.csv
# edge_califa.csv
# edge_coflux_natv.csv
# edge_hiflux.csv
# edge_coobs_DE.csv
# edge_coflux_e20.csv
# edge_coflux_smo7.csv
# edge_coobs_E.csv
# edge_coobs_D.csv
# edge_wise.csv
# edge_nsa.csv
# edge_ned.csv
# edge_leda.csv
# NGC4047_hex.2d_smo7.hdf5
# NGC4047.2d_smo7.hdf5
# rf_CO_natv.csv
# rf_HA_smo6.csv
# rf_CO_smo6.csv
# rf_HA_natv.csv
# jam_rotcurves.csv
# rprof_de20_smo.csv
# rprof_smo7_smo.csv
# bb_smo7_fixvd_dilmsk_freepa.csv
# bb_smo7_fixvd_dilmsk.csv
# bb_natv_fitvd_dilmsk.csv
# bb_natv_fixvd_dilmsk_freepa.csv
# bb_smo7_fitvd_dilmsk.csv
# bb_natv_fixvd_dilmsk.csv
# bb_natv_fitvd_dilmsk_freepa.csv
# bb_smo7_fitvd_dilmsk_freepa.csv
# cospec_iram.csv
# edge.cocube_smo7.hdf5
# edge.comom_smo7.hdf5
# edge.pipe3d.hdf5
# edge178_leda.csv
# edge_aca.2d_smo9.hdf5
# edge_aca.pipe3d.hdf5
# edge_aca_allpix.2d_smo9.hdf5
# edge_allpix.comom_smo7.hdf5
# edge_allpix.pipe3d.hdf5
# edge_califa_2019.csv
# edge_carma.2d_smo7.hdf5
# edge_carma.pipe3d.hdf5
# edge_carma_allpix.2d_smo7.hdf5
# edge_coflux_iram.csv
# edge_cospec_E20.csv
# edge_cospec_natv.csv
# edge_cospec_smo7.csv
# edge_hex.comom_smo7.hdf5
# edge_hex.pipe3d.hdf5
# edge_hispectra.csv
# edge_xsm.pipe3d.hdf5
# edgealma_hiflux.csv
# edgealma_hispectra.csv
# <EdgeTable length=0>
# <No columns>

# %% [markdown]
# ### Read a binary table.  It turns out we need to provide a path since each HDF5 file contains multiple tables.

# %%
cotab = EdgeTable('NGC4047.2d_smo7.hdf5')
# Out:
# Paths in NGC4047.2d_smo7.hdf5 :
#  ['ELINES_sm', 'SFH_sm', 'SSP_sm', 'comom_dil', 'comom_smo', 'comom_str', 'flux_elines_sm', 'indices_sm']

# %% [markdown]
# ### Try again, this time providing a path (get moments using dilated mask).

# %%
cotab = EdgeTable('NGC4047.2d_smo7.hdf5', path='comom_dil')

# %% [markdown]
# ### Get basic information about the columns

# %%
cotab.info()
# Out:
# <EdgeTable length=1849>
#    name    dtype       unit     format                   description                    n_bad
# --------- ------- ------------- ------ ------------------------------------------------ -----
#      Name  bytes7                                                           Galaxy Name     0
#        ix   int32                                    0-based pixel index in x direction     0
#        iy   int32                                    0-based pixel index in y direction     0
#    ra_abs float32           deg    .6f                                  sample ra coord     0
#   dec_abs float32           deg    .6f                                 sample dec coord     0
#    ra_off float32           deg    .6f                         ra offset from ref pixel     0
#   dec_off float32           deg    .6f                        dec offset from ref pixel     0
#   rad_arc float32        arcsec    .3f                             radius based on LEDA     0
#   azi_ang float32           deg    .3f                              azang based on LEDA     0
#  snrpk_12 float32                                         co peak signal to noise ratio   705
#   mom0_12 float32      K km / s                  co integrated intensity using dil mask  1657
# e_mom0_12 float32      K km / s                      co error in mom0 assuming dil mask  1657
#   mom1_12 float32        km / s          co intensity wgtd mean velocity using dil mask  1670
# e_mom1_12 float32        km / s                      co error in mom1 assuming dil mask  1670
#   mom2_12 float32        km / s               co intensity wgtd vel disp using dil mask  1694
# e_mom2_12 float32        km / s                      co error in mom2 assuming dil mask  1694
#    sigmol float32 solMass / pc2             apparent H2+He surf density not deprojected  1657
#  e_sigmol float32 solMass / pc2                         error in sigmol not deprojected  1657
#      cosi float32                       factor to deproject to face-on using ledaAxIncl     0
#  snrpk_13 float32                                       13co peak signal to noise ratio   648
#   mom0_13 float32      K km / s                13co integrated intensity using dil mask  1657
# e_mom0_13 float32      K km / s                    13co error in mom0 assuming dil mask  1657
#   mom1_13 float32        km / s        13co intensity wgtd mean velocity using dil mask  1673
# e_mom1_13 float32        km / s                    13co error in mom1 assuming dil mask  1670
#   mom2_13 float32        km / s             13co intensity wgtd vel disp using dil mask  1731
# e_mom2_13 float32        km / s                    13co error in mom2 assuming dil mask  1731

# %% [markdown]
# ### Get an abbreviated view of the table (two ways)

# %%
print(cotab)
# Out:
#   Name   ix  iy   ra_abs    dec_abs  ... mom1_13 e_mom1_13 mom2_13 e_mom2_13
#                    deg        deg    ...  km / s   km / s   km / s   km / s
# ------- --- --- ---------- --------- ... ------- --------- ------- ---------
# NGC4047   1   1 180.737717 48.618690 ...     nan       nan     nan       nan
# NGC4047   1   4 180.737717 48.619526 ...     nan       nan     nan       nan
# NGC4047   1   7 180.737717 48.620358 ...     nan       nan     nan       nan
# NGC4047   1  10 180.737717 48.621193 ...     nan       nan     nan       nan
# NGC4047   1  13 180.737717 48.622025 ...     nan       nan     nan       nan
# NGC4047   1  16 180.737732 48.622860 ...     nan       nan     nan       nan
# NGC4047   1  19 180.737732 48.623692 ...     nan       nan     nan       nan
# NGC4047   1  22 180.737732 48.624523 ...     nan       nan     nan       nan
# NGC4047   1  25 180.737732 48.625359 ...     nan       nan     nan       nan
# NGC4047   1  28 180.737732 48.626190 ...     nan       nan     nan       nan
#     ... ... ...        ...       ... ...     ...       ...     ...       ...
# NGC4047 127 100 180.684769 48.646191 ...     nan       nan     nan       nan
# NGC4047 127 103 180.684769 48.647026 ...     nan       nan     nan       nan
# NGC4047 127 106 180.684769 48.647858 ...     nan       nan     nan       nan
# NGC4047 127 109 180.684769 48.648693 ...     nan       nan     nan       nan
# NGC4047 127 112 180.684769 48.649525 ...     nan       nan     nan       nan
# NGC4047 127 115 180.684753 48.650356 ...     nan       nan     nan       nan
# NGC4047 127 118 180.684753 48.651192 ...     nan       nan     nan       nan
# NGC4047 127 121 180.684753 48.652023 ...     nan       nan     nan       nan
# NGC4047 127 124 180.684753 48.652859 ...     nan       nan     nan       nan
# NGC4047 127 127 180.684753 48.653690 ...     nan       nan     nan       nan
# Length = 1849 rows

# %%
cotab
# Out:
# <EdgeTable length=1849>
#   Name    ix    iy    ra_abs    dec_abs  ... mom1_13 e_mom1_13 mom2_13 e_mom2_13
#                        deg        deg    ...  km / s   km / s   km / s   km / s
#  bytes7 int32 int32  float32    float32  ... float32  float32  float32  float32
# ------- ----- ----- ---------- --------- ... ------- --------- ------- ---------
# NGC4047     1     1 180.737717 48.618690 ...     nan       nan     nan       nan
# NGC4047     1     4 180.737717 48.619526 ...     nan       nan     nan       nan
# NGC4047     1     7 180.737717 48.620358 ...     nan       nan     nan       nan
# NGC4047     1    10 180.737717 48.621193 ...     nan       nan     nan       nan
# NGC4047     1    13 180.737717 48.622025 ...     nan       nan     nan       nan
# NGC4047     1    16 180.737732 48.622860 ...     nan       nan     nan       nan
# NGC4047     1    19 180.737732 48.623692 ...     nan       nan     nan       nan
# NGC4047     1    22 180.737732 48.624523 ...     nan       nan     nan       nan
# NGC4047     1    25 180.737732 48.625359 ...     nan       nan     nan       nan
#     ...   ...   ...        ...       ... ...     ...       ...     ...       ...
# NGC4047   127   100 180.684769 48.646191 ...     nan       nan     nan       nan
# NGC4047   127   103 180.684769 48.647026 ...     nan       nan     nan       nan
# NGC4047   127   106 180.684769 48.647858 ...     nan       nan     nan       nan
# NGC4047   127   109 180.684769 48.648693 ...     nan       nan     nan       nan
# NGC4047   127   112 180.684769 48.649525 ...     nan       nan     nan       nan
# NGC4047   127   115 180.684753 48.650356 ...     nan       nan     nan       nan
# NGC4047   127   118 180.684753 48.651192 ...     nan       nan     nan       nan
# NGC4047   127   121 180.684753 48.652023 ...     nan       nan     nan       nan
# NGC4047   127   124 180.684753 48.652859 ...     nan       nan     nan       nan
# NGC4047   127   127 180.684753 48.653690 ...     nan       nan     nan       nan

# %% [markdown]
# ### Get a full view of the table

# %% [markdown]
# *Note:* The function ```show_in_notebook()``` should be called with the ```cotab.table``` object, which holds the real data stored using Astropy's Table class.  When a method is applied to ```EdgeTable``` directly (i.e. ```cotab.show_in_notebook()```), it might not work because EdgeTable is a subclass of Table. However, each EdgeTable object contains a variable called ```table```, which is a full Astropy Table.  So if any other functions work fine for Astropy Tables but do not work with EdgeTable, you can try applying the function to ```cotab.table```

# %%
#cotab.table.show_in_notebook()

# %% [markdown]
# ### Replace a column with same values expressed in different units

# %%
cotab['azi_ang'].convert_unit_to('radian')
cotab
# Out:
# <EdgeTable length=1849>
#   Name    ix    iy    ra_abs    dec_abs  ... mom1_13 e_mom1_13 mom2_13 e_mom2_13
#                        deg        deg    ...  km / s   km / s   km / s   km / s
#  bytes7 int32 int32  float32    float32  ... float32  float32  float32  float32
# ------- ----- ----- ---------- --------- ... ------- --------- ------- ---------
# NGC4047     1     1 180.737717 48.618690 ...     nan       nan     nan       nan
# NGC4047     1     4 180.737717 48.619526 ...     nan       nan     nan       nan
# NGC4047     1     7 180.737717 48.620358 ...     nan       nan     nan       nan
# NGC4047     1    10 180.737717 48.621193 ...     nan       nan     nan       nan
# NGC4047     1    13 180.737717 48.622025 ...     nan       nan     nan       nan
# NGC4047     1    16 180.737732 48.622860 ...     nan       nan     nan       nan
# NGC4047     1    19 180.737732 48.623692 ...     nan       nan     nan       nan
# NGC4047     1    22 180.737732 48.624523 ...     nan       nan     nan       nan
# NGC4047     1    25 180.737732 48.625359 ...     nan       nan     nan       nan
#     ...   ...   ...        ...       ... ...     ...       ...     ...       ...
# NGC4047   127   100 180.684769 48.646191 ...     nan       nan     nan       nan
# NGC4047   127   103 180.684769 48.647026 ...     nan       nan     nan       nan
# NGC4047   127   106 180.684769 48.647858 ...     nan       nan     nan       nan
# NGC4047   127   109 180.684769 48.648693 ...     nan       nan     nan       nan
# NGC4047   127   112 180.684769 48.649525 ...     nan       nan     nan       nan
# NGC4047   127   115 180.684753 48.650356 ...     nan       nan     nan       nan
# NGC4047   127   118 180.684753 48.651192 ...     nan       nan     nan       nan
# NGC4047   127   121 180.684753 48.652023 ...     nan       nan     nan       nan
# NGC4047   127   124 180.684753 48.652859 ...     nan       nan     nan       nan
# NGC4047   127   127 180.684753 48.653690 ...     nan       nan     nan       nan

# %% [markdown]
# ### Visualize the image data for CO, Halpha, and V-band continuuum.

# %%
import matplotlib.pyplot as plt
from edge_pydb.plotting import dotpatch, imarrayplot
hatab  = EdgeTable('NGC4047.2d_smo7.hdf5', path='ELINES_sm')
ssptab = EdgeTable('NGC4047.2d_smo7.hdf5', path='SSP_sm')

# %% [markdown]
# ### Here we use the dotpatch routine that takes an ix, iy, and data column to make a collection of colored patches.

# %%
fig, axs = plt.subplots(1, 3, figsize=(14,4), sharex=True, sharey=True)

img, xymin, xymax = dotpatch(cotab['ix'], cotab['iy'], cotab['mom0_12'], axes=axs[0], vmin=0, cmap='jet')
axs[0].set_title('CO intensity image')
axs[0].set_xlim([28,106])
axs[0].set_ylim([28,106])
axs[0].set_aspect('equal')
plt.colorbar(img, ax=axs[0])

img, xymin, xymax = dotpatch(hatab['ix'], hatab['iy'], hatab['Halpha_sm'], axes=axs[1], cmap='jet')
axs[1].set_title(r'H$\alpha$ image')
axs[1].set_aspect('equal')
plt.colorbar(img, ax=axs[1])

img, xymin, xymax = dotpatch(ssptab['ix'], ssptab['iy'], ssptab['Vcont_ssp_sm'], axes=axs[2], cmap='jet')
axs[2].set_title('V continuum')
axs[2].set_aspect('equal')
plt.colorbar(img, ax=axs[2])

# %% [markdown]
# ### Here we use the imarrayplot routine and the '_sm' tables instead.  Due to the reduced sampling in the database the maximum image limits are now [0...43].

# %%
fig, axs = plt.subplots(1, 3, figsize=(14,4), sharex=True, sharey=True)

img, xymin, xymax = imarrayplot(cotab['ix'], cotab['iy'], cotab['mom0_12'], axes=axs[0], cmap='jet')
axs[0].set_title('CO intensity image')
axs[0].set_aspect('equal')
plt.colorbar(img, ax=axs[0])

img, xymin, xymax = imarrayplot(hatab['ix'], hatab['iy'], hatab['Halpha_sm'], axes=axs[1], cmap='jet')
axs[1].set_title(r'H$\alpha$ (7" res)')
axs[1].set_aspect('equal')
plt.colorbar(img, ax=axs[1])

img, xymin, xymax = imarrayplot(ssptab['ix'], ssptab['iy'], ssptab['Vcont_ssp_sm'], axes=axs[2], cmap='jet')
axs[2].set_title('V continuum (7" res)')
axs[2].set_aspect('equal')
plt.colorbar(img, ax=axs[2])

# %% [markdown]
# ### Hexagonally sampled points (still experimental)

# %%
fig, axs = plt.subplots(1, 3, figsize=(14,4), sharex=True, sharey=True)

cotab = EdgeTable('NGC4047_hex.2d_smo7.hdf5', path='comom_dil')
img, xymin, xymax = dotpatch(cotab['ix'], cotab['iy'], cotab['mom0_12'], axes=axs[0], vmin=0, cmap='jet')
axs[0].set_title('CO intensity image')
axs[0].set_xlim([28,106])
axs[0].set_ylim([28,106])
axs[0].set_aspect('equal')
plt.colorbar(img, ax=axs[0])

hatab = EdgeTable('NGC4047_hex.2d_smo7.hdf5', path='ELINES_sm')
img, xymin, xymax = dotpatch(hatab['ix'], hatab['iy'], hatab['Halpha_sm'], axes=axs[1], cmap='jet')
axs[1].set_title(r'H$\alpha$ image')
axs[1].set_aspect('equal')
plt.colorbar(img, ax=axs[1])

ssptab = EdgeTable('NGC4047_hex.2d_smo7.hdf5', path='SSP_sm')
img, xymin, xymax = dotpatch(ssptab['ix'], ssptab['iy'], ssptab['Vcont_ssp_sm'], axes=axs[2], cmap='jet')
axs[2].set_title('V continuum')
axs[2].set_aspect('equal')
plt.colorbar(img, ax=axs[2])
